# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tokenize import TreebankWordTokenizer
from nltk.tag import pos_tag
from nltk import ne_chunk, Tree
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /Users/John/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/John/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/John/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /Users/John/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
f = open('/Users/John/Trump_MiamiFL_Sep-16-16.txt','r')
ex = f.readlines()
f.close()
len(ex)
# Out:
# 122

# %%
strEx = " ".join(str(x) for x in ex)

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
sent = preprocess(strEx)
sent
# Out:
# [('Thank', 'NNP'),
#  ('you', 'PRP'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('so', 'RB'),
#  ('great', 'JJ'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('in', 'IN'),
#  ('my', 'PRP$'),
#  ('second', 'JJ'),
#  ('home', 'NN'),
#  (',', ','),
#  ('Florida', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('city', 'NN'),
#  ('of', 'IN'),
#  ('Miami', 'NNP'),
#  ('where', 'WRB'),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('so', 'RB'),
#  ('many', 'JJ'),
#  ('wonderful', 'JJ'),
#  ('friends', 'NNS'),
#  ('and', 'CC'),
#  ('employees', 'NNS'),
#  ('.', '.'),
#  ('New', 'NNP'),
#  ('polls', 'NNS'),
#  ('have', 'VBP'),
#  ('just', 'RB'),
#  ('come', 'VBN'),
#  ('in', 'IN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('we', 'PRP'),
#  ("'re", 'VBP'),
#  ('leading', 'VBG'),
#  ('in', 'IN'),
#  ('battleground', 'NN'),
#  ('states', 'NNS'),
#  ('all', 'DT'),
#  ('over', 'IN'),
#  ('this', 'DT'),
#  ('country', 'NN'),
#  ('-', ':'),
#  ('including', 'VBG'),
#  ('four', 'CD'),
#  ('points', 'NNS'),
#  ('here', 'RB'),
#  ('in', 'IN'),
#  ('Florida', 'NNP'),
#  ('.', '.'),
#  ('LA', 'NNP'),
#  ('Times', 'NNP'),
#  ('has', 'VBZ'),
#  ('us', 'PRP'),
#  ('up', 'RP'),
#  ('6', 'CD'),
#  ('points', 'NNS'),
#  ('nationwide', 'JJ'),
#  ('.', '.'),
#  ('Come', 'NNP'),
#  ('November', 'NNP'),
#  ('8th', 'CD'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('are', 'VBP'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('win', 'VB'),
#  ('Florida', 'NNP'),
#  ('and', 'CC'),
#  ('we', 'PRP'),
#  ('are', 'VBP'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('win', 'VB'),
#  ('the', 'DT'),
#  ('White', 'NNP'),
#  ('House', 'NNP'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ("'s", 'VBZ'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('a', 'DT'),
#  ('victory', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('people', 'NNS'),
#  ('-', ':'),
#  ('it', 'PRP'),
#  ("'s", 'VBZ'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('a', 'DT'),
#  ('victory', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('workers', 'NNS'),
#  (',', ','),
#  ('the', 'DT'),
#  ('families', 'NNS'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Veterans', 'NNPS'),
#  (',', ','),
#  ('the', 'DT'),
#  ('everyday', 'JJ'),
#  ('citizens', 'NNS'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('it', 'PRP'),
#  ("'s", 'VBZ'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('a', 'DT'),
#  ('victory', 'NN'),
#  ('for', 'IN'),
#  ('those', 'DT'),
#  ('who', 'WP'),
#  ('have', 'VBP'),
#  ("n't", 'RB'),
#  ('had', 'VBD'),
#  ('reason', 'NN'),
#  ('for', 'IN'),
#  ('hope', 'NN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('long', 'JJ'),
#  ('time', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ("'m", 'VBP'),
#  ('campaigning', 'VBG'),
#  ('in', 'IN'),
#  ('every', 'DT'),
#  ('community', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('every', 'DT'),
#  ('part', 'NN'),
#  ('of', 'IN'),
#  ('this', 'DT'),
#  ('country', 'NN'),
#  (',', ','),
#  ('for', 'IN'),
#  ('every', 'DT'),
#  ('last', 'JJ'),
#  ('vote', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('am', 'VBP'),
#  ('running', 'VBG'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('a', 'DT'),
#  ('President', 'NNP'),
#  ('for', 'IN'),
#  ('all', 'DT'),
#  ('Americans', 'NNPS'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('just', 'RB'),
#  ('had', 'VBD'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('amazing', 'JJ'),
#  ('afternoon', 'NN'),
#  ('in', 'IN'),
#  ('Little', 'NNP'),
#  ('Haiti', 'NNP'),
#  ('and', 'CC'),
#  ('I', 'PRP'),
#  ("'m", 'VBP'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('campaigning', 'VBG'),
#  ('hard', 'JJ'),
#  ('for', 'IN'),
#  ('their', 'PRP$'),
#  ('votes', 'NNS'),
#  ('.', '.'),
#  ('What', 'WP'),
#  ('incredible', 'JJ'),
#  ('people', 'NNS'),
#  ('.', '.'),
#  ('Our', 'PRP$'),
#  ('support', 'NN'),
#  ('comes', 'VBZ'),
#  ('from', 'IN'),
#  ('all', 'DT'),
#  ('regions', 'NNS'),
#  (',', ','),
#  ('all', 'DT'),
#  ('backgrounds', 'NNS'),
#  ('and', 'CC'),
#  ('all', 'DT'),
#  ('walks', 'NNS'),
#  ('of', 'IN'),
#  ('life', 'NN'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ('are', 'VBP'),
#  ('cops', 'NNS'),
#  ('and', 'CC'),
#  ('soldiers', 'NNS'),
#  (',', ','),
#  ('carpenters', 'NNS'),
#  ('and', 'CC'),
#  ('welders', 'NNS'),
#  (',', ','),
#  ('accountants', 'NNS'),
#  ('and', 'CC'),
#  ('lawyers', 'NNS'),
#  (',', ','),
#  ('young', 'JJ'),
#  ('and', 'CC'),
#  ('old', 'JJ'),
#  (',', ','),
#  ('rich', 'JJ'),
#  ('and', 'CC'),
#  ('poor', 'JJ'),
#  (',', ','),
#  ('black', 'JJ'),
#  (',', ','),
#  ('white', 'JJ'),
#  ('and', 'CC'),
#  ('Hispanic', 'JJ'),
#  ('-', ':'),
#  ('but', 'CC'),
#  ('above', 'IN'),
#  ('all', 'DT'),
#  ('else', 'RB'),
#  (',', ','),
#  ('you', 'PRP'),
#  ('are', 'VBP'),
#  ('American', 'JJ'),
#  ('.', '.'),
#  ('Just', 'RB'),
#  ('today', 'NN'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('was', 'VBD'),
#  ('honored', 'VBN'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('the', 'DT'),
#  ('endorsement', 'NN'),
#  ('of', 'IN'),
#  ('recipients', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Medal', 'NNP'),
#  ('of', 'IN'),
#  ('Honor', 'NNP'),
#  ('and', 'CC'),
#  ('many', 'JJ'),
#  ('of', 'IN'),
#  ('our', 'PRP$'),
#  ('amazing', 'JJ'),
#  ('military', 'JJ'),
#  ('leaders', 'NNS'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('now', 'RB'),
#  ('have', 'VBP'),
#  ('the', 'DT'),
#  ('endorsements', 'NNS'),
#  ('of', 'IN'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('160', 'CD'),
#  ('top', 'JJ'),
#  ('generals', 'NNS'),
#  ('and', 'CC'),
#  ('Admirals', 'NNS'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('also', 'RB'),
#  ('have', 'VBP'),
#  ('the', 'DT'),
#  ('support', 'NN'),
#  ('of', 'IN'),
#  ('16,500', 'CD'),
#  ('Border', 'NNP'),
#  ('Patrol', 'NNP'),
#  ('Officers', 'NNP'),
#  ('-', ':'),
#  ('as', 'RB'),
#  ('well', 'RB'),
#  ('as', 'IN'),
#  ('law', 'NN'),
#  ('enforcement', 'NN'),
#  ('officers', 'NNS'),
#  ('across', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('we', 'PRP'),
#  ('have', 'VBP'),
#  ('the', 'DT'),
#  ('support', 'NN'),
#  ('of', 'IN'),
#  ('millions', 'NNS'),
#  ('of', 'IN'),
#  ('patriotic', 'JJ'),
#  ('Moms', 'NNP'),
#  ('and', 'CC'),
#  ('Dads', 'NNP'),
#  ('who', 'WP'),
#  ('go', 'VBP'),
#  ('to', 'TO'),
#  ('work', 'VB'),
#  ('every', 'DT'),
#  ('day', 'NN'),
#  ('and', 'CC'),
#  ('make', 'VB'),
#  ('this', 'DT'),
#  ('country', 'NN'),
#  ('run', 'VB'),
#  ('.', '.'),
#  ('While', 'IN'),
#  ('my', 'PRP$'),
#  ('opponent', 'NN'),
#  ('slanders', 'NNS'),
#  ('you', 'PRP'),
#  ('as', 'IN'),
#  ('deplorable', 'JJ'),
#  ('and', 'CC'),
#  ('irredeemable', 'JJ'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('call', 'VBP'),
#  ('you', 'PRP'),
#  ('hardworking', 'VBG'),
#  ('American', 'JJ'),
#  ('patriots', 'NNS'),
#  ('who', 'WP'),
#  ('love', 'VBP'),
#  ('your', 'PRP$'),
#  ('family', 'NN'),
#  ('and', 'CC'),
#  ('love', 'VB'),
#  ('your', 'PRP$'),
#  ('country', 'NN'),
#  ('.', '.'),
#  ('Clinton', 'NNP'),
#  ("'s", 'POS'),
#  ('campaign', 'NN'),
#  ('relies', 'VBZ'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('tired', 'JJ'),
#  ('tactic', 'NN'),
#  ('of', 'IN'),
#  ('smearing', 'VBG'),
#  ('opponents', 'NNS'),
#  ('who', 'WP'),
#  ('question', 'VBP'),
#  ('her', 'PRP$'),
#  ('policies', 'NNS'),
#  ('as', 'IN'),
#  ('racists', 'NNS'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ("'s", 'VBZ'),
#  ('the', 'DT'),
#  ('oldest', 'JJS'),
#  ('play', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Democratic', 'JJ'),
#  ('play', 'NN'),
#  ('book', 'NN'),
#  ('-', ':'),
#  ('and', 'CC'),
#  ('Americans', 'NNPS'),
#  ('have', 'VBP'),
#  ('had', 'VBN'),
#  ('enough', 'VBN'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('want', 'VBP'),
#  ('solutions', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('they', 'PRP'),
#  ('want', 'VBP'),
#  ('better', 'JJR'),
#  ('lives', 'NNS'),
#  ('-', ':'),
#  ('not', 'RB'),
#  ('more', 'RBR'),
#  ('petty', 'JJ'),
#  ('attacks', 'NNS'),
#  ('from', 'IN'),
#  ('failed', 'VBN'),
#  ('and', 'CC'),
#  ('discredited', 'VBN'),
#  ('politicians', 'NNS'),
#  ('.', '.'),
#  ('People', 'NNS'),
#  ('who', 'WP'),
#  ('want', 'VBP'),
#  ('their', 'PRP$'),
#  ('immigration', 'NN'),
#  ('laws', 'NNS'),
#  ('enforced', 'VBD'),
#  (',', ','),
#  ('and', 'CC'),
#  ('their', 'PRP$'),
#  ('borders', 'NNS'),
#  ('secured', 'VBN'),
#  (',', ','),
#  ('are', 'VBP'),
#  ('not', 'RB'),
#  ('racists', 'NNS'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('are', 'VBP'),
#  ('patriotic', 'JJ'),
#  ('Americans', 'NNPS'),
#  ('of', 'IN'),
#  ('all', 'DT'),
#  ('backgrounds', 'NNS'),
#  ('who', 'WP'),
#  ('want', 'VBP'),
#  ('their', 'PRP$'),
#  ('jobs', 'NNS'),
#  ('and', 'CC'),
#  ('families', 'NNS'),
#  ('protected', 'VBN'),
#  ('.', '.'),
#  ('People', 'NNS'),
#  ('who', 'WP'),
#  ('warn', 'VBP'),
#  ('about', 'IN'),
#  ('Radical', 'NNP'),
#  ('Islamic', 'NNP'),
#  ('Terrorism', 'NNP'),
#  ('are', 'VBP'),
#  ('not', 'RB'),
#  ('Islamophobes', 'NNP'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('are', 'VBP'),
#  ('decent', 'JJ'),
#  ('American', 'JJ'),
#  ('citizens', 'NNS'),
#  ('who', 'WP'),
#  ('want', 'VBP'),
#  ('to', 'TO'),
#  ('uphold', 'VB'),
#  ('our', 'PRP$'),
#  ('tolerant', 'NN'),
#  ('values', 'NNS'),
#  ('and', 'CC'),
#  ('keep', 'VB'),
#  ('our', 'PRP$'),
#  ('country', 'NN'),
#  ('safe', 'JJ'),
#  ('.', '.'),
#  ('People', 'NNS'),
#  ('who', 'WP'),
#  ('support', 'VBP'),
#  ('the', 'DT'),
#  ('police', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('who', 'WP'),
#  ('want', 'VBP'),
#  ('crime', 'NN'),
#  ('reduced', 'VBN'),
#  (',', ','),
#  ('are', 'VBP'),
#  ('not', 'RB'),
#  ('prejudiced', 'VBN'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('are', 'VBP'),
#  ('concerned', 'JJ'),
#  ('and', 'CC'),
#  ('loving', 'JJ'),
#  ('citizens', 'NNS'),
#  ('whose', 'WP$'),
#  ('hearts', 'NNS'),
#  ('break', 'VBP'),
#  ('every', 'DT'),
#  ('time', 'NN'),
#  ('an', 'DT'),
#  ('innocent', 'JJ'),
#  ('child', 'NN'),
#  ('is', 'VBZ'),
#  ('lost', 'VBN'),
#  ('to', 'TO'),
#  ('preventable', 'JJ'),
#  ('violence', 'NN'),
#  ('.', '.'),
#  ('Yet', 'CC'),
#  (',', ','),
#  ('while', 'IN'),
#  ('she', 'PRP'),
#  ('lives', 'VBZ'),
#  ('behind', 'IN'),
#  ('gates', 'NNS'),
#  ('and', 'CC'),
#  ('walls', 'NNS'),
#  ('and', 'CC'),
#  ('guards', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('raises', 'VBZ'),
#  ('millions', 'NNS'),
#  ('from', 'IN'),
#  ('hedge', 'NN'),
#  ('fund', 'NN'),
#  ('managers', 'NNS'),
#  ('and', 'CC'),
#  ('Wall', 'NNP'),
#  ('Street', 'NNP'),
#  ('donors', 'NNS'),
#  (',', ','),
#  ('she', 'PRP'),
#  ('slanders', 'NNS'),
#  ('and', 'CC'),
#  ('smears', 'NNS'),
#  ('working', 'VBG'),
#  ('people', 'NNS'),
#  ('who', 'WP'),
#  ('just', 'RB'),
#  ('want', 'VBP'),
#  ('a', 'DT'),
#  ('fraction', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('security', 'NN'),
#  ('enjoyed', 'VBN'),
#  ('by', 'IN'),
#  ('our', 'PRP$'),
#  ('politicians', 'NNS'),
#  ('.', '.'),
#  ('Her', 'PRP$'),
#  ('comments', 'NNS'),
#  ('displayed', 'VBD'),
#  ('the', 'DT'),
#  ('same', 'JJ'),
#  ('sense', 'NN'),
#  ('of', 'IN'),
#  ('arrogance', 'NN'),
#  ('and', 'CC'),
#  ('entitlement', 'NN'),
#  ('that', 'WDT'),
#  ('led', 'VBD'),
#  ('her', 'PRP'),
#  ('to', 'TO'),
#  ('violate', 'VB'),
#  ('federal', 'JJ'),
#  ('law', 'NN'),
#  ('as', 'IN'),
#  ('Secretary', 'NNP'),
#  ('of', 'IN'),
#  ('State', 'NNP'),
#  (',', ','),
#  ('hide', 'NN'),
#  ('and', 'CC'),
#  ('delete', 'VB'),
#  ('her', 'PRP$'),
#  ('emails', 'NNS'),
#  (',', ','),
#  ('destroy', 'VB'),
#  ('her', 'PRP$'),
#  ('phones', 'NNS'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('hammer', 'NN'),
#  (',', ','),
#  ('put', 'VBD'),
#  ('classified', 'VBN'),
#  ('information', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('reach', 'NN'),
#  ('of', 'IN'),
#  ('our', 'PRP$'),
#  ('enemies', 'NNS'),
#  (',', ','),
#  ('lie', 'NN'),
#  ('to', 'TO'),
#  ('Congress', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('sell', 'VB'),
#  ('government', 'NN'),
#  ('favors', 'NNS'),
#  ('and', 'CC'),
#  ('access', 'NN'),
#  ('through', 'IN'),
#  ('the', 'DT'),
#  ('Clinton', 'NNP'),
#  ('Foundation', 'NNP'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ("'s", 'VBZ'),
#  ('the', 'DT'),
#  ('same', 'JJ'),
#  ('attitude', 'NN'),
#  ('of', 'IN'),
#  ('arrogance', 'NN'),
#  ('and', 'CC'),
#  ('entitlement', 'NN'),
#  ('that', 'IN'),
#  ('explains', 'VBZ'),
#  ('why', 'WRB'),
#  ('she', 'PRP'),
#  ('has', 'VBZ'),
#  ('never', 'RB'),
#  ('taken', 'VBN'),
#  ('accountability', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('disasters', 'NNS'),
#  ('she', 'PRP'),
#  ('created', 'VBD'),
#  ('in', 'IN'),
#  ('Libya', 'NNP'),
#  (',', ','),
#  ('Syria', 'NNP'),
#  (',', ','),
#  ('Iraq', 'NNP'),
#  (',', ','),
#  ('Iran', 'NNP'),
#  ('and', 'CC'),
#  ('all', 'DT'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ("'s", 'VBZ'),
#  ('the', 'DT'),
#  ('same', 'JJ'),
#  ('reason', 'NN'),
#  ('why', 'WRB'),
#  ('she', 'PRP'),
#  ('wo', 'MD'),
#  ("n't", 'RB'),
#  ('take', 'VB'),
#  ('responsibility', 'NN'),
#  ('for', 'IN'),
#  ('her', 'PRP$'),
#  ('central', 'JJ'),
#  ('role', 'NN'),
#  ('in', 'IN'),
#  ('unleashing', 'JJ'),
#  ('ISIS', 'NNP'),
#  ('.', '.'),
#  ('Her', 'PRP$'),
#  ('policies', 'NNS'),
#  ('have', 'VBP'),
#  ('created', 'VBN'),
#  ('disaster', 'NN'),
#  ('overseas', 'RB'),
#  (',', ','),
#  ('and', 'CC'),
#  ('poverty', 'NN'),
#  ('at', 'IN'),
#  ('home', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('am', 'VBP'),
#  ('running', 'VBG'),
#  ('to', 'TO'),
#  ('reverse', 'VB'),
#  ('these', 'DT'),
#  ('failures', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('create', 'VB'),
#  ('a', 'DT'),
#  ('New', 'NNP'),
#  ('American', 'JJ'),
#  ('future', 'NN'),
#  ('.', '.'),
#  ('That', 'IN'),
#  ('future', 'JJ'),
#  ('begins', 'VBZ'),
#  ('with', 'IN'),
#  ('prosperity', 'NN'),
#  ('at', 'IN'),
#  ('home', 'NN'),
#  ('.', '.'),
#  ('My', 'PRP$'),
#  ('economic', 'JJ'),
#  ('agenda', 'NN'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('summed', 'VBN'),
#  ('up', 'RP'),
#  ('in', 'IN'),
#  ('three', 'CD'),
#  ('words', 'NNS'),
#  (':', ':'),
#  ('jobs', 'NNS'),
#  (',', ','),
#  ('jobs', 'NNS'),
#  (',', ','),
#  ('jobs', 'NNS'),
#  ('.', '.'),
#  ('One', 'CD'),
#  ('of', 'IN'),
#  ('my', 'PRP$'),
#  ('highest', 'JJS'),
#  ('priorities', 'NNS'),
#  ('is', 'VBZ'),
#  ('to', 'TO'),
#  ('bring', 'VB'),
#  ('jobs', 'NNS'),
#  ('into', 'IN'),
#  ('our', 'PRP$'),
#  ('inner', 'JJ'),
#  ('cities', 'NNS'),
#  ('.', '.'),
#  ('African-Americans', 'JJ'),
#  ('communities', 'NNS'),
#  ('have', 'VBP'),
#  ('suffered', 'VBN'),
#  ('horribly', 'RB'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('result', 'NN'),
#  ('of', 'IN'),
#  ('failed', 'VBN'),
#  ('Democratic', 'JJ'),
#  ('leadership', 'NN'),
#  ('.', '.'),
#  ('Democrats', 'NNPS'),
#  ('have', 'VBP'),
#  ('run', 'VBN'),
#  ('these', 'DT'),
#  ('inner', 'JJ'),
#  ('cities', 'NNS'),
#  ('for', 'IN'),
#  ('half', 'PDT'),
#  ('a', 'DT'),
#  ('century', 'NN'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('control', 'VBP'),
#  ('the', 'DT'),
#  ('mayors', 'NNS'),
#  ("'", 'POS'),
#  ('offices', 'NNS'),
#  (',', ','),
#  ('the', 'DT'),
#  ('school', 'NN'),
#  ('boards', 'NNS'),
#  (',', ','),
#  ('the', 'DT'),
#  ('city', 'NN'),
#  ('councils', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('seats', 'NNS'),
#  ('in', 'IN'),
#  ('Congress', 'NNP'),
#  ('-', ':'),
#  ('and', 'CC'),
#  ('all', 'DT'),
#  ('they', 'PRP'),
#  ('have', 'VBP'),
#  ('delivered', 'VBN'),
#  ('is', 'VBZ'),
#  ('more', 'RBR'),
#  ('poverty', 'NN'),
#  (',', ','),
#  ('more', 'JJR'),
#  ('crime', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('more', 'RBR'),
#  ('failing', 'JJ'),
#  ('schools', 'NNS'),
#  ('.', '.'),
#  ('45', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('African-American', 'JJ'),
#  ('children', 'NNS'),
#  ('under', 'IN'),
#  ('the', 'DT'),
#  ('age', 'NN'),
#  ('of', 'IN'),
#  ('6', 'CD'),
#  ('now', 'RB'),
#  ('live', 'VBP'),
#  ('in', 'IN'),
#  ('poverty', 'NN'),
#  ('.', '.'),
#  ('More', 'JJR'),
#  ('than', 'IN'),
#  ('3,000', 'CD'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('shot', 'VBN'),
#  ('in', 'IN'),
#  ('Chicago', 'NNP'),
#  ('this', 'DT'),
#  ('year', 'NN'),
#  ('alone', 'RB'),
#  ('.', '.'),
#  ('58', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('African-American', 'JJ'),
#  ('youth', 'NN'),
#  ('are', 'VBP'),
#  ('not', 'RB'),
#  ('working', 'VBG'),
#  ('.', '.'),
#  ('These', 'DT'),
#  ('are', 'VBP'),
#  ('the', 'DT'),
#  ('results', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('policies', 'NNS'),
#  ('embraced', 'VBN'),
#  ('by', 'IN'),
#  ('Hillary', 'NNP'),
#  ('Clinton', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('everyone', 'NN'),
#  ('knows', 'VBZ'),
#  ('that', 'IN'),
#  ('if', 'IN'),
#  ('she', 'PRP'),
#  ("'s", 'VBZ'),
#  ('elected', 'VBN'),
#  ('the', 'DT'),
#  ('inner', 'JJ'),
#  ('cities', 'NNS'),
#  ('will', 'MD'),
#  ('get', 'VB'),
#  ('nothing', 'NN'),
#  ('but', 'CC'),
#  ('more', 'JJR'),
#  ('pain', 'NN'),
#  ('and', 'CC'),
#  ('more', 'JJR'),
#  ('suffering', 'NN'),
#  ('.', '.'),
#  ('Hillary', 'NNP'),
#  ('Clinton', 'NNP'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('there', 'RB'),
#  ('in', 'IN'),
#  ('Washington', 'NNP'),
#  ('for', 'IN'),
#  ('30', 'CD'),
#  ('years', 'NNS'),
#  ('-', ':'),
#  ('her', 'PRP$'),
#  ('disastrous', 'JJ'),
#  ('record', 'NN'),
#  ('speaks', 'NN'),
#  ('for', 'IN'),
#  ('itself', 'PRP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('only', 'JJ'),
#  ('people', 'NNS'),
#  ('she', 'PRP'),
#  ('delivers', 'NNS'),
#  ('for', 'IN'),
#  ('is', 'VBZ'),
#  ('her', 'PRP$'),
#  ('donors', 'NNS'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('am', 'VBP'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('deliver', 'VB'),
#  ('for', 'IN'),
#  ('you', 'PRP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('American', 'JJ'),
#  ('people', 'NNS'),
#  ('.', '.'),
#  ('If', 'IN'),
#  ('we', 'PRP'),
#  ('lower', 'VBP'),
#  ('our', 'PRP$'),
#  ('taxes', 'NNS'),
#  (',', ','),
#  ('remove', 'VB'),
#  ('destructive', 'JJ'),
#  ('regulations', 'NNS'),
#  (',', ','),
#  ('unleash', 'VBP'),
#  ('the', 'DT'),
#  ('vast', 'JJ'),
#  ('treasure', 'NN'),
#  ('of', 'IN'),
#  ('American', 'NNP'),
#  ('energy', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('negotiate', 'JJ'),
#  ('trade', 'NN'),
#  ('deals', 'NNS'),
#  ('that', 'WDT'),
#  ('put', 'VBD'),
#  ('America', 'NNP'),
#  ('First', 'NNP'),
#  (',', ','),
#  ('then', 'RB'),
#  ('there', 'EX'),
#  ('is', 'VBZ'),
#  ('no', 'DT'),
#  ('limit', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('number', 'NN'),
#  ('of', 'IN'),
#  ('jobs', 'NNS'),
#  ('we', 'PRP'),
#  ('can', 'MD'),
#  ('create', 'VB'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('amount', 'NN'),
#  ('of', 'IN'),
#  ('prosperity', 'NN'),
#  ('we', 'PRP'),
#  ('can', 'MD'),
#  ('unleash', 'VB'),
#  ('.', '.'),
#  ('My', 'PRP$'),
#  ('first', 'JJ'),
#  ('day', 'NN'),
#  ('in', 'IN'),
#  ('office', 'NN'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('am', 'VBP'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('order', 'NN'),
#  ('a', 'DT'),
#  ('review', 'NN'),
#  ('of', 'IN'),
#  ('every', 'DT'),
#  ('single', 'JJ'),
#  ('regulation', 'NN'),
#  ('issued', 'VBN'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('last', 'JJ'),
#  ('eight', 'CD'),
#  ('years', 'NNS'),
#  ('.', '.'),
#  ('All', 'DT'),
#  ('needless', 'JJ'),
#  (',', ','),
#  ('job-killing', 'JJ'),
#  ('regulations', 'NNS'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('cancelled', 'VBN'),
#  ('.', '.'),
#  ('Millions', 'NNS'),
#  ('of', 'IN'),
#  ('new', 'JJ'),
#  ('jobs', 'NNS'),
#  ('will', 'MD'),
#  ('come', 'VB'),
#  ('pouring', 'NN'),
#  ('in', 'IN'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('are', 'VBP'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ...]

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'
cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)
print(cs)
# Out:
# (S
#   Thank/NNP
#   you/PRP
#   ./.
#   It/PRP
#   is/VBZ
#   so/RB
#   great/JJ
#   to/TO
#   be/VB
#   in/IN
#   my/PRP$
#   (NP second/JJ home/NN)
#   ,/,
#   Florida/NNP
#   ,/,
#   and/CC
#   in/IN
#   (NP the/DT city/NN)
#   of/IN
#   Miami/NNP
#   where/WRB
#   I/PRP
#   have/VBP
#   so/RB
#   many/JJ
#   wonderful/JJ
#   friends/NNS
#   and/CC
#   employees/NNS
#   ./.
#   New/NNP
#   polls/NNS
#   have/VBP
#   just/RB
#   come/VBN
#   in/IN
#   ,/,
#   and/CC
#   we/PRP
#   're/VBP
#   leading/VBG
#   in/IN
#   (NP battleground/NN)
#   states/NNS
#   all/DT
#   over/IN
#   (NP this/DT country/NN)
#   -/:
#   including/VBG
#   four/CD
#   points/NNS
#   here/RB
#   in/IN
#   Florida/NNP
#   ./.
#   LA/NNP
#   Times/NNP
#   has/VBZ
#   us/PRP
#   up/RP
#   6/CD
#   points/NNS
#   nationwide/JJ
#   ./.
#   Come/NNP
#   November/NNP
#   8th/CD
#   ,/,
#   we/PRP
#   are/VBP
#   going/VBG
#   to/TO
#   win/VB
#   Florida/NNP
#   and/CC
#   we/PRP
#   are/VBP
#   going/VBG
#   to/TO
#   win/VB
#   the/DT
#   White/NNP
#   House/NNP
#   ./.
#   It/PRP
#   's/VBZ
#   going/VBG
#   to/TO
#   be/VB
#   (NP a/DT victory/NN)
#   for/IN
#   the/DT
#   people/NNS
#   -/:
#   it/PRP
#   's/VBZ
#   going/VBG
#   to/TO
#   be/VB
#   (NP a/DT victory/NN)
#   for/IN
#   the/DT
#   workers/NNS
#   ,/,
#   the/DT
#   families/NNS
#   ,/,
#   the/DT
#   Veterans/NNPS
#   ,/,
#   the/DT
#   everyday/JJ
#   citizens/NNS
#   ./.
#   And/CC
#   it/PRP
#   's/VBZ
#   going/VBG
#   to/TO
#   be/VB
#   (NP a/DT victory/NN)
#   for/IN
#   those/DT
#   who/WP
#   have/VBP
#   n't/RB
#   had/VBD
#   (NP reason/NN)
#   for/IN
#   (NP hope/NN)
#   in/IN
#   (NP a/DT long/JJ time/NN)
#   ./.
#   I/PRP
#   'm/VBP
#   campaigning/VBG
#   in/IN
#   (NP every/DT community/NN)
#   ,/,
#   and/CC
#   (NP every/DT part/NN)
#   of/IN
#   (NP this/DT country/NN)
#   ,/,
#   for/IN
#   (NP every/DT last/JJ vote/NN)
#   ./.
#   I/PRP
#   am/VBP
#   running/VBG
#   to/TO
#   be/VB
#   a/DT
#   President/NNP
#   for/IN
#   all/DT
#   Americans/NNPS
#   ./.
#   I/PRP
#   just/RB
#   had/VBD
#   the/DT
#   most/RBS
#   (NP amazing/JJ afternoon/NN)
#   in/IN
#   Little/NNP
#   Haiti/NNP
#   and/CC
#   I/PRP
#   'm/VBP
#   going/VBG
#   to/TO
#   be/VB
#   campaigning/VBG
#   hard/JJ
#   for/IN
#   their/PRP$
#   votes/NNS
#   ./.
#   What/WP
#   incredible/JJ
#   people/NNS
#   ./.
#   Our/PRP$
#   (NP support/NN)
#   comes/VBZ
#   from/IN
#   all/DT
#   regions/NNS
#   ,/,
#   all/DT
#   backgrounds/NNS
#   and/CC
#   all/DT
#   walks/NNS
#   of/IN
#   (NP life/NN)
#   ./.
#   You/PRP
#   are/VBP
#   cops/NNS
#   and/CC
#   soldiers/NNS
#   ,/,
#   carpenters/NNS
#   and/CC
#   welders/NNS
#   ,/,
#   accountants/NNS
#   and/CC
#   lawyers/NNS
#   ,/,
#   young/JJ
#   and/CC
#   old/JJ
#   ,/,
#   rich/JJ
#   and/CC
#   poor/JJ
#   ,/,
#   black/JJ
#   ,/,
#   white/JJ
#   and/CC
#   Hispanic/JJ
#   -/:
#   but/CC
#   above/IN
#   all/DT
#   else/RB
#   ,/,
#   you/PRP
#   are/VBP
#   American/JJ
#   ./.
#   Just/RB
#   (NP today/NN)
#   ,/,
#   I/PRP
#   was/VBD
#   honored/VBN
#   to/TO
#   get/VB
#   (NP the/DT endorsement/NN)
#   of/IN
#   recipients/NNS
#   of/IN
#   the/DT
#   Medal/NNP
#   of/IN
#   Honor/NNP
#   and/CC
#   many/JJ
#   of/IN
#   our/PRP$
#   amazing/JJ
#   military/JJ
#   leaders/NNS
#   ./.
#   We/PRP
#   now/RB
#   have/VBP
#   the/DT
#   endorsements/NNS
#   of/IN
#   more/JJR
#   than/IN
#   160/CD
#   top/JJ
#   generals/NNS
#   and/CC
#   Admirals/NNS
#   ./.
#   We/PRP
#   also/RB
#   have/VBP
#   (NP the/DT support/NN)
#   of/IN
#   16,500/CD
#   Border/NNP
#   Patrol/NNP
#   Officers/NNP
#   -/:
#   as/RB
#   well/RB
#   as/IN
#   (NP law/NN)
#   (NP enforcement/NN)
#   officers/NNS
#   across/IN
#   (NP the/DT country/NN)
#   ./.
#   And/CC
#   we/PRP
#   have/VBP
#   (NP the/DT support/NN)
#   of/IN
#   millions/NNS
#   of/IN
#   patriotic/JJ
#   Moms/NNP
#   and/CC
#   Dads/NNP
#   who/WP
#   go/VBP
#   to/TO
#   work/VB
#   (NP every/DT day/NN)
#   and/CC
#   make/VB
#   (NP this/DT country/NN)
#   run/VB
#   ./.
#   While/IN
#   my/PRP$
#   (NP opponent/NN)
#   slanders/NNS
#   you/PRP
#   as/IN
#   deplorable/JJ
#   and/CC
#   irredeemable/JJ
#   ,/,
#   I/PRP
#   call/VBP
#   you/PRP
#   hardworking/VBG
#   American/JJ
#   patriots/NNS
#   who/WP
#   love/VBP
#   your/PRP$
#   (NP family/NN)
#   and/CC
#   love/VB
#   your/PRP$
#   (NP country/NN)
#   ./.
#   Clinton/NNP
#   's/POS
#   (NP campaign/NN)
#   relies/VBZ
#   on/IN
#   (NP the/DT tired/JJ tactic/NN)
#   of/IN
#   smearing/VBG
#   opponents/NNS
#   who/WP
#   question/VBP
#   her/PRP$
#   policies/NNS
#   as/IN
#   racists/NNS
#   ./.
#   It/PRP
#   's/VBZ
#   the/DT
#   oldest/JJS
#   (NP play/NN)
#   in/IN
#   (NP the/DT Democratic/JJ play/NN)
#   (NP book/NN)
#   -/:
#   and/CC
#   Americans/NNPS
#   have/VBP
#   had/VBN
#   enough/VBN
#   ./.
#   They/PRP
#   want/VBP
#   solutions/NNS
#   ,/,
#   and/CC
#   they/PRP
#   want/VBP
#   better/JJR
#   lives/NNS
#   -/:
#   not/RB
#   more/RBR
#   petty/JJ
#   attacks/NNS
#   from/IN
#   failed/VBN
#   and/CC
#   discredited/VBN
#   politicians/NNS
#   ./.
#   People/NNS
#   who/WP
#   want/VBP
#   their/PRP$
#   (NP immigration/NN)
#   laws/NNS
#   enforced/VBD
#   ,/,
#   and/CC
#   their/PRP$
#   borders/NNS
#   secured/VBN
#   ,/,
#   are/VBP
#   not/RB
#   racists/NNS
#   ./.
#   They/PRP
#   are/VBP
#   patriotic/JJ
#   Americans/NNPS
#   of/IN
#   all/DT
#   backgrounds/NNS
#   who/WP
#   want/VBP
#   their/PRP$
#   jobs/NNS
#   and/CC
#   families/NNS
#   protected/VBN
#   ./.
#   People/NNS
#   who/WP
#   warn/VBP
#   about/IN
#   Radical/NNP
#   Islamic/NNP
#   Terrorism/NNP
#   are/VBP
#   not/RB
#   Islamophobes/NNP
#   ./.
#   They/PRP
#   are/VBP
#   decent/JJ
#   American/JJ
#   citizens/NNS
#   who/WP
#   want/VBP
#   to/TO
#   uphold/VB
#   our/PRP$
#   (NP tolerant/NN)
#   values/NNS
#   and/CC
#   keep/VB
#   our/PRP$
#   (NP country/NN)
#   safe/JJ
#   ./.
#   People/NNS
#   who/WP
#   support/VBP
#   (NP the/DT police/NN)
#   ,/,
#   and/CC
#   who/WP
#   want/VBP
#   (NP crime/NN)
#   reduced/VBN
#   ,/,
#   are/VBP
#   not/RB
#   prejudiced/VBN
#   ./.
#   They/PRP
#   are/VBP
#   concerned/JJ
#   and/CC
#   loving/JJ
#   citizens/NNS
#   whose/WP$
#   hearts/NNS
#   break/VBP
#   (NP every/DT time/NN)
#   (NP an/DT innocent/JJ child/NN)
#   is/VBZ
#   lost/VBN
#   to/TO
#   (NP preventable/JJ violence/NN)
#   ./.
#   Yet/CC
#   ,/,
#   while/IN
#   she/PRP
#   lives/VBZ
#   behind/IN
#   gates/NNS
#   and/CC
#   walls/NNS
#   and/CC
#   guards/NNS
#   ,/,
#   and/CC
#   raises/VBZ
#   millions/NNS
#   from/IN
#   (NP hedge/NN)
#   (NP fund/NN)
#   managers/NNS
#   and/CC
#   Wall/NNP
#   Street/NNP
#   donors/NNS
#   ,/,
#   she/PRP
#   slanders/NNS
#   and/CC
#   smears/NNS
#   working/VBG
#   people/NNS
#   who/WP
#   just/RB
#   want/VBP
#   (NP a/DT fraction/NN)
#   of/IN
#   (NP the/DT security/NN)
#   enjoyed/VBN
#   by/IN
#   our/PRP$
#   politicians/NNS
#   ./.
#   Her/PRP$
#   comments/NNS
#   displayed/VBD
#   (NP the/DT same/JJ sense/NN)
#   of/IN
#   (NP arrogance/NN)
#   and/CC
#   (NP entitlement/NN)
#   that/WDT
#   led/VBD
#   her/PRP
#   to/TO
#   violate/VB
#   (NP federal/JJ law/NN)
#   as/IN
#   Secretary/NNP
#   of/IN
#   State/NNP
#   ,/,
#   (NP hide/NN)
#   and/CC
#   delete/VB
#   her/PRP$
#   emails/NNS
#   ,/,
#   destroy/VB
#   her/PRP$
#   phones/NNS
#   with/IN
#   (NP a/DT hammer/NN)
#   ,/,
#   put/VBD
#   classified/VBN
#   (NP information/NN)
#   in/IN
#   (NP the/DT reach/NN)
#   of/IN
#   our/PRP$
#   enemies/NNS
#   ,/,
#   (NP lie/NN)
#   to/TO
#   Congress/NNP
#   ,/,
#   and/CC
#   sell/VB
#   (NP government/NN)
#   favors/NNS
#   and/CC
#   (NP access/NN)
#   through/IN
#   the/DT
#   Clinton/NNP
#   Foundation/NNP
#   ./.
#   It/PRP
#   's/VBZ
#   (NP the/DT same/JJ attitude/NN)
#   of/IN
#   (NP arrogance/NN)
#   and/CC
#   (NP entitlement/NN)
#   that/IN
#   explains/VBZ
#   why/WRB
#   she/PRP
#   has/VBZ
#   never/RB
#   taken/VBN
#   (NP accountability/NN)
#   for/IN
#   the/DT
#   disasters/NNS
#   she/PRP
#   created/VBD
#   in/IN
#   Libya/NNP
#   ,/,
#   Syria/NNP
#   ,/,
#   Iraq/NNP
#   ,/,
#   Iran/NNP
#   and/CC
#   all/DT
#   over/IN
#   (NP the/DT world/NN)
#   ./.
#   It/PRP
#   's/VBZ
#   (NP the/DT same/JJ reason/NN)
#   why/WRB
#   she/PRP
#   wo/MD
#   n't/RB
#   take/VB
#   (NP responsibility/NN)
#   for/IN
#   her/PRP$
#   (NP central/JJ role/NN)
#   in/IN
#   unleashing/JJ
#   ISIS/NNP
#   ./.
#   Her/PRP$
#   policies/NNS
#   have/VBP
#   created/VBN
#   (NP disaster/NN)
#   overseas/RB
#   ,/,
#   and/CC
#   (NP poverty/NN)
#   at/IN
#   (NP home/NN)
#   ./.
#   I/PRP
#   am/VBP
#   running/VBG
#   to/TO
#   reverse/VB
#   these/DT
#   failures/NNS
#   ,/,
#   and/CC
#   create/VB
#   a/DT
#   New/NNP
#   (NP American/JJ future/NN)
#   ./.
#   That/IN
#   future/JJ
#   begins/VBZ
#   with/IN
#   (NP prosperity/NN)
#   at/IN
#   (NP home/NN)
#   ./.
#   My/PRP$
#   (NP economic/JJ agenda/NN)
#   can/MD
#   be/VB
#   summed/VBN
#   up/RP
#   in/IN
#   three/CD
#   words/NNS
#   :/:
#   jobs/NNS
#   ,/,
#   jobs/NNS
#   ,/,
#   jobs/NNS
#   ./.
#   One/CD
#   of/IN
#   my/PRP$
#   highest/JJS
#   priorities/NNS
#   is/VBZ
#   to/TO
#   bring/VB
#   jobs/NNS
#   into/IN
#   our/PRP$
#   inner/JJ
#   cities/NNS
#   ./.
#   African-Americans/JJ
#   communities/NNS
#   have/VBP
#   suffered/VBN
#   horribly/RB
#   as/IN
#   (NP a/DT result/NN)
#   of/IN
#   failed/VBN
#   (NP Democratic/JJ leadership/NN)
#   ./.
#   Democrats/NNPS
#   have/VBP
#   run/VBN
#   these/DT
#   inner/JJ
#   cities/NNS
#   for/IN
#   half/PDT
#   (NP a/DT century/NN)
#   ./.
#   They/PRP
#   control/VBP
#   the/DT
#   mayors/NNS
#   '/POS
#   offices/NNS
#   ,/,
#   (NP the/DT school/NN)
#   boards/NNS
#   ,/,
#   (NP the/DT city/NN)
#   councils/NNS
#   ,/,
#   and/CC
#   the/DT
#   seats/NNS
#   in/IN
#   Congress/NNP
#   -/:
#   and/CC
#   all/DT
#   they/PRP
#   have/VBP
#   delivered/VBN
#   is/VBZ
#   more/RBR
#   (NP poverty/NN)
#   ,/,
#   more/JJR
#   (NP crime/NN)
#   ,/,
#   and/CC
#   more/RBR
#   failing/JJ
#   schools/NNS
#   ./.
#   45/CD
#   (NP %/NN)
#   of/IN
#   African-American/JJ
#   children/NNS
#   under/IN
#   (NP the/DT age/NN)
#   of/IN
#   6/CD
#   now/RB
#   live/VBP
#   in/IN
#   (NP poverty/NN)
#   ./.
#   More/JJR
#   than/IN
#   3,000/CD
#   have/VBP
#   been/VBN
#   shot/VBN
#   in/IN
#   Chicago/NNP
#   (NP this/DT year/NN)
#   alone/RB
#   ./.
#   58/CD
#   (NP %/NN)
#   of/IN
#   (NP African-American/JJ youth/NN)
#   are/VBP
#   not/RB
#   working/VBG
#   ./.
#   These/DT
#   are/VBP
#   the/DT
#   results/NNS
#   of/IN
#   the/DT
#   policies/NNS
#   embraced/VBN
#   by/IN
#   Hillary/NNP
#   Clinton/NNP
#   ,/,
#   and/CC
#   (NP everyone/NN)
#   knows/VBZ
#   that/IN
#   if/IN
#   she/PRP
#   's/VBZ
#   elected/VBN
#   the/DT
#   inner/JJ
#   cities/NNS
#   will/MD
#   get/VB
#   (NP nothing/NN)
#   but/CC
#   more/JJR
#   (NP pain/NN)
#   and/CC
#   more/JJR
#   (NP suffering/NN)
#   ./.
#   Hillary/NNP
#   Clinton/NNP
#   has/VBZ
#   been/VBN
#   there/RB
#   in/IN
#   Washington/NNP
#   for/IN
#   30/CD
#   years/NNS
#   -/:
#   her/PRP$
#   (NP disastrous/JJ record/NN)
#   (NP speaks/NN)
#   for/IN
#   itself/PRP
#   ./.
#   The/DT
#   only/JJ
#   people/NNS
#   she/PRP
#   delivers/NNS
#   for/IN
#   is/VBZ
#   her/PRP$
#   donors/NNS
#   ./.
#   I/PRP
#   am/VBP
#   going/VBG
#   to/TO
#   deliver/VB
#   for/IN
#   you/PRP
#   ,/,
#   the/DT
#   American/JJ
#   people/NNS
#   ./.
#   If/IN
#   we/PRP
#   lower/VBP
#   our/PRP$
#   taxes/NNS
#   ,/,
#   remove/VB
#   destructive/JJ
#   regulations/NNS
#   ,/,
#   unleash/VBP
#   (NP the/DT vast/JJ treasure/NN)
#   of/IN
#   American/NNP
#   (NP energy/NN)
#   ,/,
#   and/CC
#   (NP negotiate/JJ trade/NN)
#   deals/NNS
#   that/WDT
#   put/VBD
#   America/NNP
#   First/NNP
#   ,/,
#   then/RB
#   there/EX
#   is/VBZ
#   (NP no/DT limit/NN)
#   to/TO
#   (NP the/DT number/NN)
#   of/IN
#   jobs/NNS
#   we/PRP
#   can/MD
#   create/VB
#   and/CC
#   (NP the/DT amount/NN)
#   of/IN
#   (NP prosperity/NN)
#   we/PRP
#   can/MD
#   unleash/VB
#   ./.
#   My/PRP$
#   (NP first/JJ day/NN)
#   in/IN
#   (NP office/NN)
#   ,/,
#   I/PRP
#   am/VBP
#   going/VBG
#   to/TO
#   (NP order/NN)
#   (NP a/DT review/NN)
#   of/IN
#   (NP every/DT single/JJ regulation/NN)
#   issued/VBN
#   over/IN
#   the/DT
#   last/JJ
#   eight/CD
#   years/NNS
#   ./.
#   All/DT
#   needless/JJ
#   ,/,
#   job-killing/JJ
#   regulations/NNS
#   will/MD
#   be/VB
#   cancelled/VBN
#   ./.
#   Millions/NNS
#   of/IN
#   new/JJ
#   jobs/NNS
#   will/MD
#   come/VB
#   (NP pouring/NN)
#   in/IN
#   ./.
#   We/PRP
#   are/VBP
#   going/VBG
#   to/TO
#   lift/VB
#   the/DT
#   restrictions/NNS
#   on/IN
#   American/NNP
#   (NP energy/NN)
#   -/:
#   which/WDT
#   means/VBZ
#   at/IN
#   least/JJS
#   (NP another/DT half/NN)
#   a/DT
#   million/CD
#   new/JJ
#   jobs/NNS
#   (NP a/DT year/NN)
#   ./.
#   That/DT
#   's/VBZ
#   just/RB
#   (NP the/DT beginning/NN)
#   ./.
#   Also/RB
#   on/IN
#   my/PRP$
#   (NP first/JJ day/NN)
#   ,/,
#   I/PRP
#   am/VBP
#   going/VBG
#   to/TO
#   ask/VB
#   Congress/NNP
#   to/TO
#   send/VB
#   me/PRP
#   (NP a/DT bill/NN)
#   to/TO
#   immediately/RB
#   repeal/VB
#   and/CC
#   replace/VB
#   disastrous/JJ
#   Obamacare/NNP
#   -/:
#   this/DT
#   will/MD
#   instantly/RB
#   save/VB
#   another/DT
#   2/CD
#   million/CD
#   jobs/NNS
#   ./.
#   I/PRP
#   am/VBP
#   also/RB
#   going/VBG
#   to/TO
#   completely/RB
#   reform/VB
#   our/PRP$
#   (NP trade/NN)
#   deals/NNS
#   ./.
#   We/PRP
#   are/VBP
#   going/VBG
#   to/TO
#   renegotiate/VB
#   NAFTA/NNP
#   ,/,
#   stand/VBP
#   up/RP
#   to/TO
#   China/NNP
#   ,/,
#   and/CC
#   keep/VB
#   America/NNP
#   out/IN
#   of/IN
#   the/DT
#   TPP/NNP
#   ./.
#   We/PRP
#   do/VBP
#   n't/RB
#   need/VB
#   (NP another/DT massive/JJ multinational/NN)
#   (NP deal/NN)
#   that/WDT
#   ties/VBZ
#   us/PRP
#   up/RP
#   and/CC
#   binds/VBZ
#   us/PRP
#   down/RP
#   ./.
#   (NP Another/DT major/JJ reform/NN)
#   is/VBZ
#   going/VBG
#   to/TO
#   be/VB
#   (NP school/NN)
#   (NP choice/NN)
#   ./.
#   I/PRP
#   've/VBP
#   outlined/VBN
#   (NP a/DT plan/NN)
#   to/TO
#   provide/VB
#   (NP every/DT disadvantaged/JJ child/NN)
#   in/IN
#   America/NNP
#   (NP the/DT freedom/NN)
#   to/TO
#   choose/VB
#   the/DT
#   private/JJ
#   ,/,
#   public/JJ
#   ,/,
#   (NP magnet/NN)
#   or/CC
#   (NP religious/JJ school/NN)
#   of/IN
#   his/PRP$
#   or/CC
#   her/PRP$
#   (NP choice/NN)
#   ./.
#   This/DT
#   will/MD
#   help/VB
#   lift/VB
#   millions/NNS
#   of/IN
#   poor/JJ
#   African-American/JJ
#   and/CC
#   Hispanic/JJ
#   children/NNS
#   out/IN
#   of/IN
#   (NP poverty/NN)
#   ./.
#   Since/IN
#   President/NNP
#   Obama/NNP
#   came/VBD
#   into/IN
#   (NP office/NN)
#   ,/,
#   another/DT
#   2/CD
#   million/CD
#   Hispanic-Americans/NNS
#   have/VBP
#   fallen/VBN
#   into/IN
#   (NP poverty/NN)
#   ./.
#   This/DT
#   is/VBZ
#   unacceptable/JJ
#   ./.
#   To/TO
#   the/DT
#   Hispanic/NNP
#   (NP community/NN)
#   I/PRP
#   say/VBP
#   :/:
#   we/PRP
#   are/VBP
#   going/VBG
#   to/TO
#   protect/VB
#   your/PRP$
#   jobs/NNS
#   ,/,
#   we/PRP
#   are/VBP
#   going/VBG
#   to/TO
#   build/VB
#   up/RP
#   your/PRP$
#   schools/NNS
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   going/VBG
#   to/TO
#   deliver/VB
#   (NP safety/NN)
#   and/CC
#   (NP opportunity/NN)
#   for/IN
#   your/PRP$
#   children/NNS
#   ./.
#   Earlier/RBR
#   (NP this/DT week/NN)
#   ,/,
#   I/PRP
#   also/RB
#   rolled/VBD
#   out/RP
#   (NP a/DT plan/NN)
#   to/TO
#   help/VB
#   our/PRP$
#   mothers/NNS
#   and/CC
#   our/PRP$
#   families/NNS
#   get/VBP
#   affordable/JJ
#   ,/,
#   (NP quality/NN)
#   (NP childcare/NN)
#   for/IN
#   their/PRP$
#   children/NNS
#   ./.
#   On/IN
#   (NP policy/NN)
#   after/IN
#   (NP policy/NN)
#   ,/,
#   we/PRP
#   are/VBP
#   going/VBG
#   to/TO
#   provide/VB
#   (NP opportunity/NN)
#   ,/,
#   (NP prosperity/NN)
#   and/CC
#   (NP security/NN)
#   for/IN
#   all/DT
#   Americans/NNPS
#   ./.
#   We/PRP
#   are/VBP
#   also/RB
#   going/VBG
#   to/TO
#   stand/VB
#   with/IN
#   the/DT
#   Cuban/NNP
#   people/NNS
#   in/IN
#   their/PRP$
#   (NP fight/NN)
#   against/IN
#   (NP communist/JJ oppression/NN)
#   ./.
#   The/DT
#   President/NNP
#   's/POS
#   (NP one-sided/JJ deal/NN)
#   for/IN
#   Cuba/NNP
#   benefits/NNS
#   only/RB
#   the/DT
#   Castro/NNP
#   Regime/NNP
#   ./.
#   But/CC
#   all/DT
#   of/IN
#   the/DT
#   concessions/NNS
#   that/WDT
#   Barack/NNP
#   Obama/NNP
#   has/VBZ
#   granted/VBN
#   the/DT
#   Castro/NNP
#   Regime/NNP
#   were/VBD
#   done/VBN
#   through/IN
#   (NP executive/NN)
#   (NP order/NN)
#   ,/,
#   which/WDT
#   means/VBZ
#   the/DT
#   next/JJ
#   President/NNP
#   can/MD
#   reverse/VB
#   them/PRP
#   -/:
#   and/CC
#   that/DT
#   is/VBZ
#   what/WP
#   I/PRP
#   will/MD
#   do/VB
#   ,/,
#   unless/IN
#   the/DT
#   Castro/NNP
#   Regime/NNP
#   meets/VBZ
#   our/PRP$
#   demands/NNS
#   ./.
#   Those/DT
#   demands/NNS
#   will/MD
#   include/VB
#   religious/JJ
#   and/CC
#   (NP political/JJ freedom/NN)
#   for/IN
#   the/DT
#   Cuban/NNP
#   people/NNS
#   ./.
#   Let/VB
#   's/POS
#   also/RB
#   talk/VBP
#   about/IN
#   Venezuela/NNP
#   ./.
#   Venezuela/NNP
#   is/VBZ
#   a/DT
#   beautiful/JJ
#   ,/,
#   vibrant/JJ
#   ,/,
#   and/CC
#   (NP resource-rich/JJ country/NN)
#   ,/,
#   filled/VBN
#   with/IN
#   amazing/JJ
#   and/CC
#   hardworking/VBG
#   people/NNS
#   ./.
#   But/CC
#   Venezuela/NNP
#   has/VBZ
#   been/VBN
#   run/VBN
#   into/IN
#   (NP the/DT ground/NN)
#   by/IN
#   socialists/NNS
#   ./.
#   The/DT
#   next/JJ
#   President/NNP
#   of/IN
#   the/DT
#   United/NNP
#   States/NNPS
#   must/MD
#   stand/VB
#   in/IN
#   (NP solidarity/NN)
#   with/IN
#   all/DT
#   people/NNS
#   oppressed/VBN
#   in/IN
#   our/PRP$
#   (NP hemisphere/NN)
#   ,/,
#   and/CC
#   I/PRP
#   will/MD
#   stand/VB
#   with/IN
#   the/DT
#   oppressed/JJ
#   people/NNS
#   of/IN
#   Venezuela/NNP
#   yearning/VBG
#   to/TO
#   be/VB
#   free/JJ
#   ./.
#   Here/RB
#   ,/,
#   in/IN
#   America/NNP
#   ,/,
#   I/PRP
#   will/MD
#   push/VB
#   to/TO
#   expand/VB
#   (NP freedom/NN)
#   for/IN
#   all/DT
#   of/IN
#   our/PRP$
#   people/NNS
#   ./.
#   I/PRP
#   am/VBP
#   going/VBG
#   to/TO
#   lower/VB
#   you/PRP
#   taxes/NNS
#   ;/:
#   I/PRP
#   am/VBP
#   going/VBG
#   to/TO
#   get/VB
#   rid/JJ
#   of/IN
#   massive/JJ
#   amounts/NNS
#   of/IN
#   unnecessary/JJ
#   regulations/NNS
#   ,/,
#   on/IN
#   (NP business/NN)
#   and/CC
#   in/IN
#   your/PRP$
#   (NP life/NN)
#   ;/:
#   I/PRP
#   'm/VBP
#   going/VBG
#   to/TO
#   repeal/VB
#   and/CC
#   replace/VB
#   Obamacare/NNP
#   ;/:
#   I/PRP
#   'm/VBP
#   going/VBG
#   to/TO
#   appoint/VB
#   Justices/NNS
#   to/TO
#   the/DT
#   Supreme/NNP
#   Court/NNP
#   who/WP
#   will/MD
#   follow/VB
#   the/DT
#   Constitution/NNP
#   ;/:
#   I/PRP
#   'm/VBP
#   going/VBG
#   to/TO
#   rebuild/VB
#   our/PRP$
#   depleted/JJ
#   military/JJ
#   and/CC
#   take/VB
#   (NP care/NN)
#   of/IN
#   our/PRP$
#   vets/NNS
#   ;/:
#   I/PRP
#   'm/VBP
#   going/VBG
#   to/TO
#   save/VB
#   your/PRP$
#   2nd/CD
#   (NP amendment/NN)
#   ;/:
#   I/PRP
#   'm/VBP
#   going/VBG
#   to/TO
#   stop/VB
#   (NP illegal/JJ immigration/NN)
#   and/CC
#   drugs/NNS
#   coming/VBG
#   into/IN
#   our/PRP$
#   (NP country/NN)
#   ,/,
#   and/CC
#   yes/RB
#   ,/,
#   we/PRP
#   will/MD
#   build/VB
#   (NP the/DT wall/NN)
#   and/CC
#   I/PRP
#   'm/VBP
#   going/VBG
#   to/TO
#   renegotiate/VB
#   our/PRP$
#   (NP disastrous/JJ trade/NN)
#   deals/NNS
#   ,/,
#   especially/RB
#   NAFTA/NNP
#   -/:
#   and/CC
#   we/PRP
#   will/MD
#   make/VB
#   (NP great/JJ trade/NN)
#   deals/NNS
#   that/WDT
#   put/VBD
#   the/DT
#   American/NNP
#   (NP worker/NN)
#   first/RB
#   ./.
#   We/PRP
#   will/MD
#   rebuild/VB
#   our/PRP$
#   roads/NNS
#   ,/,
#   bridges/NNS
#   ,/,
#   tunnels/NNS
#   ,/,
#   highways/NNS
#   ,/,
#   airports/NNS
#   ,/,
#   schools/NNS
#   and/CC
#   hospitals/NNS
#   ./.
#   American/JJ
#   cars/NNS
#   will/MD
#   travel/VB
#   the/DT
#   roads/NNS
#   ,/,
#   American/NNP
#   planes/NNS
#   will/MD
#   soar/VB
#   in/IN
#   the/DT
#   skies/NNS
#   ,/,
#   and/CC
#   American/NNP
#   ships/NNS
#   will/MD
#   patrol/VB
#   the/DT
#   seas/NNS
#   ./.
#   (NP American/JJ steel/NN)
#   will/MD
#   send/VB
#   new/JJ
#   skyscrapers/NNS
#   into/IN
#   (NP the/DT clouds/NN)
#   ./.
#   American/JJ
#   hands/NNS
#   will/MD
#   rebuild/VB
#   (NP this/DT nation/NN)
#   -/:
#   and/CC
#   American/NNP
#   (NP energy/NN)
#   ,/,
#   mined/VBN
#   from/IN
#   American/JJ
#   sources/NNS
#   ,/,
#   will/MD
#   (NP power/NN)
#   (NP this/DT nation/NN)
#   ./.
#   American/JJ
#   workers/NNS
#   will/MD
#   be/VB
#   hired/VBN
#   to/TO
#   do/VB
#   (NP the/DT job/NN)
#   ./.
#   We/PRP
#   will/MD
#   put/VB
#   (NP new/JJ American/JJ steel/NN)
#   into/IN
#   (NP the/DT spine/NN)
#   of/IN
#   (NP this/DT country/NN)
#   ./.
#   I/PRP
#   will/MD
#   fight/VB
#   for/IN
#   (NP every/DT neglected/JJ part/NN)
#   of/IN
#   (NP this/DT nation/NN)
#   -/:
#   and/CC
#   I/PRP
#   will/MD
#   fight/VB
#   to/TO
#   bring/VB
#   us/PRP
#   all/DT
#   together/RB
#   as/IN
#   One/CD
#   American/JJ
#   People/NNP
#   ./.
#   Imagine/VB
#   what/WP
#   our/PRP$
#   (NP country/NN)
#   could/MD
#   accomplish/VB
#   if/IN
#   we/PRP
#   started/VBD
#   working/VBG
#   together/RB
#   as/IN
#   One/CD
#   (NP People/NN)
#   ,/,
#   under/IN
#   One/CD
#   God/NNP
#   ,/,
#   saluting/VBG
#   One/CD
#   American/JJ
#   Flag/NNP
#   ./.
#   It/PRP
#   is/VBZ
#   (NP time/NN)
#   to/TO
#   break/VB
#   with/IN
#   the/DT
#   bitter/JJ
#   failures/NNS
#   of/IN
#   (NP the/DT past/NN)
#   ,/,
#   and/CC
#   to/TO
#   embrace/VB
#   a/DT
#   new/JJ
#   ,/,
#   inclusive/JJ
#   and/CC
#   (NP prosperous/JJ American/JJ future/NN)
#   ./.
#   Jobs/NNP
#   will/MD
#   return/VB
#   ,/,
#   incomes/NNS
#   will/MD
#   rise/VB
#   ,/,
#   and/CC
#   new/JJ
#   factories/NNS
#   will/MD
#   come/VB
#   rushing/VBG
#   back/RB
#   to/TO
#   our/PRP$
#   shores/NNS
#   ./.
#   Once/RB
#   more/JJR
#   ,/,
#   we/PRP
#   will/MD
#   have/VB
#   (NP a/DT government/NN)
#   of/IN
#   ,/,
#   by/IN
#   and/CC
#   for/IN
#   the/DT
#   people/NNS
#   ./.
#   We/PRP
#   Will/NNP
#   Make/NNP
#   America/NNP
#   Prosperous/NNP
#   Again/NNP
#   ./.
#   We/PRP
#   Will/NNP
#   Make/NNP
#   America/NNP
#   Strong/NNP
#   Again/NNP
#   ./.
#   And/CC
#   Will/NNP
#   Make/NNP
#   America/NNP
#   Great/NNP
#   Again/NNP
#   ./.
#   Thank/NNP
#   you/PRP
#   ,/,
#   and/CC
#   God/NNP
#   Bless/NNP
#   !/.
#   (NP /NN))

# %%
tree1 = nltk.Tree('NP',['Alick'])
print(tree1)
tree2 = nltk.Tree('N',['Alick','Rabbit'])
print(tree2)
tree3 = nltk.Tree('S',[tree1,tree2])
print(tree3.label())
tree3.draw()
# Out:
# (NP Alick)
# (N Alick Rabbit)
# S

# %%
NER = ne_chunk(nltk.pos_tag(word_tokenize(strEx)), binary=False)

# %%
type(NER)
# Out:
# nltk.tree.Tree

# %%
print(NER)
# Out:
# (S
#   Thank/NNP
#   you/PRP
#   ./.
#   It/PRP
#   is/VBZ
#   so/RB
#   great/JJ
#   to/TO
#   be/VB
#   in/IN
#   my/PRP$
#   second/JJ
#   home/NN
#   ,/,
#   (GPE Florida/NNP)
#   ,/,
#   and/CC
#   in/IN
#   the/DT
#   city/NN
#   of/IN
#   (GPE Miami/NNP)
#   where/WRB
#   I/PRP
#   have/VBP
#   so/RB
#   many/JJ
#   wonderful/JJ
#   friends/NNS
#   and/CC
#   employees/NNS
#   ./.
#   New/NNP
#   polls/NNS
#   have/VBP
#   just/RB
#   come/VBN
#   in/IN
#   ,/,
#   and/CC
#   we/PRP
#   're/VBP
#   leading/VBG
#   in/IN
#   battleground/NN
#   states/NNS
#   all/DT
#   over/IN
#   this/DT
#   country/NN
#   -/:
#   including/VBG
#   four/CD
#   points/NNS
#   here/RB
#   in/IN
#   (GPE Florida/NNP)
#   ./.
#   LA/NNP
#   Times/NNP
#   has/VBZ
#   us/PRP
#   up/RP
#   6/CD
#   points/NNS
#   nationwide/JJ
#   ./.
#   Come/NNP
#   November/NNP
#   8th/CD
#   ,/,
#   we/PRP
#   are/VBP
#   going/VBG
#   to/TO
#   win/VB
#   (PERSON Florida/NNP)
#   and/CC
#   we/PRP
#   are/VBP
#   going/VBG
#   to/TO
#   win/VB
#   the/DT
#   (FACILITY White/NNP House/NNP)
#   ./.
#   It/PRP
#   's/VBZ
#   going/VBG
#   to/TO
#   be/VB
#   a/DT
#   victory/NN
#   for/IN
#   the/DT
#   people/NNS
#   -/:
#   it/PRP
#   's/VBZ
#   going/VBG
#   to/TO
#   be/VB
#   a/DT
#   victory/NN
#   for/IN
#   the/DT
#   workers/NNS
#   ,/,
#   the/DT
#   families/NNS
#   ,/,
#   the/DT
#   (ORGANIZATION Veterans/NNPS)
#   ,/,
#   the/DT
#   everyday/JJ
#   citizens/NNS
#   ./.
#   And/CC
#   it/PRP
#   's/VBZ
#   going/VBG
#   to/TO
#   be/VB
#   a/DT
#   victory/NN
#   for/IN
#   those/DT
#   who/WP
#   have/VBP
#   n't/RB
#   had/VBD
#   reason/NN
#   for/IN
#   hope/NN
#   in/IN
#   a/DT
#   long/JJ
#   time/NN
#   ./.
#   I/PRP
#   'm/VBP
#   campaigning/VBG
#   in/IN
#   every/DT
#   community/NN
#   ,/,
#   and/CC
#   every/DT
#   part/NN
#   of/IN
#   this/DT
#   country/NN
#   ,/,
#   for/IN
#   every/DT
#   last/JJ
#   vote/NN
#   ./.
#   I/PRP
#   am/VBP
#   running/VBG
#   to/TO
#   be/VB
#   a/DT
#   President/NNP
#   for/IN
#   all/DT
#   Americans/NNPS
#   ./.
#   I/PRP
#   just/RB
#   had/VBD
#   the/DT
#   most/RBS
#   amazing/JJ
#   afternoon/NN
#   in/IN
#   (GPE Little/NNP Haiti/NNP)
#   and/CC
#   I/PRP
#   'm/VBP
#   going/VBG
#   to/TO
#   be/VB
#   campaigning/VBG
#   hard/JJ
#   for/IN
#   their/PRP$
#   votes/NNS
#   ./.
#   What/WP
#   incredible/JJ
#   people/NNS
#   ./.
#   Our/PRP$
#   support/NN
#   comes/VBZ
#   from/IN
#   all/DT
#   regions/NNS
#   ,/,
#   all/DT
#   backgrounds/NNS
#   and/CC
#   all/DT
#   walks/NNS
#   of/IN
#   life/NN
#   ./.
#   You/PRP
#   are/VBP
#   cops/NNS
#   and/CC
#   soldiers/NNS
#   ,/,
#   carpenters/NNS
#   and/CC
#   welders/NNS
#   ,/,
#   accountants/NNS
#   and/CC
#   lawyers/NNS
#   ,/,
#   young/JJ
#   and/CC
#   old/JJ
#   ,/,
#   rich/JJ
#   and/CC
#   poor/JJ
#   ,/,
#   black/JJ
#   ,/,
#   white/JJ
#   and/CC
#   (ORGANIZATION Hispanic/JJ)
#   -/:
#   but/CC
#   above/IN
#   all/DT
#   else/RB
#   ,/,
#   you/PRP
#   are/VBP
#   (GPE American/JJ)
#   ./.
#   Just/RB
#   today/NN
#   ,/,
#   I/PRP
#   was/VBD
#   honored/VBN
#   to/TO
#   get/VB
#   the/DT
#   endorsement/NN
#   of/IN
#   recipients/NNS
#   of/IN
#   the/DT
#   (ORGANIZATION Medal/NNP)
#   of/IN
#   (GPE Honor/NNP)
#   and/CC
#   many/JJ
#   of/IN
#   our/PRP$
#   amazing/JJ
#   military/JJ
#   leaders/NNS
#   ./.
#   We/PRP
#   now/RB
#   have/VBP
#   the/DT
#   endorsements/NNS
#   of/IN
#   more/JJR
#   than/IN
#   160/CD
#   top/JJ
#   generals/NNS
#   and/CC
#   (ORGANIZATION Admirals/NNS)
#   ./.
#   We/PRP
#   also/RB
#   have/VBP
#   the/DT
#   support/NN
#   of/IN
#   16,500/CD
#   (PERSON Border/NNP Patrol/NNP Officers/NNP)
#   -/:
#   as/RB
#   well/RB
#   as/IN
#   law/NN
#   enforcement/NN
#   officers/NNS
#   across/IN
#   the/DT
#   country/NN
#   ./.
#   And/CC
#   we/PRP
#   have/VBP
#   the/DT
#   support/NN
#   of/IN
#   millions/NNS
#   of/IN
#   patriotic/JJ
#   Moms/NNP
#   and/CC
#   Dads/NNP
#   who/WP
#   go/VBP
#   to/TO
#   work/VB
#   every/DT
#   day/NN
#   and/CC
#   make/VB
#   this/DT
#   country/NN
#   run/VB
#   ./.
#   While/IN
#   my/PRP$
#   opponent/NN
#   slanders/NNS
#   you/PRP
#   as/IN
#   deplorable/JJ
#   and/CC
#   irredeemable/JJ
#   ,/,
#   I/PRP
#   call/VBP
#   you/PRP
#   hardworking/VBG
#   (GPE American/JJ)
#   patriots/NNS
#   who/WP
#   love/VBP
#   your/PRP$
#   family/NN
#   and/CC
#   love/VB
#   your/PRP$
#   country/NN
#   ./.
#   (PERSON Clinton/NNP)
#   's/POS
#   campaign/NN
#   relies/VBZ
#   on/IN
#   the/DT
#   tired/JJ
#   tactic/NN
#   of/IN
#   smearing/VBG
#   opponents/NNS
#   who/WP
#   question/VBP
#   her/PRP$
#   policies/NNS
#   as/IN
#   racists/NNS
#   ./.
#   It/PRP
#   's/VBZ
#   the/DT
#   oldest/JJS
#   play/NN
#   in/IN
#   the/DT
#   (ORGANIZATION Democratic/JJ)
#   play/NN
#   book/NN
#   -/:
#   and/CC
#   (GPE Americans/NNPS)
#   have/VBP
#   had/VBN
#   enough/VBN
#   ./.
#   They/PRP
#   want/VBP
#   solutions/NNS
#   ,/,
#   and/CC
#   they/PRP
#   want/VBP
#   better/JJR
#   lives/NNS
#   -/:
#   not/RB
#   more/RBR
#   petty/JJ
#   attacks/NNS
#   from/IN
#   failed/VBN
#   and/CC
#   discredited/VBN
#   politicians/NNS
#   ./.
#   People/NNS
#   who/WP
#   want/VBP
#   their/PRP$
#   immigration/NN
#   laws/NNS
#   enforced/VBD
#   ,/,
#   and/CC
#   their/PRP$
#   borders/NNS
#   secured/VBN
#   ,/,
#   are/VBP
#   not/RB
#   racists/NNS
#   ./.
#   They/PRP
#   are/VBP
#   patriotic/JJ
#   Americans/NNPS
#   of/IN
#   all/DT
#   backgrounds/NNS
#   who/WP
#   want/VBP
#   their/PRP$
#   jobs/NNS
#   and/CC
#   families/NNS
#   protected/VBN
#   ./.
#   People/NNS
#   who/WP
#   warn/VBP
#   about/IN
#   (PERSON Radical/NNP Islamic/NNP Terrorism/NNP)
#   are/VBP
#   not/RB
#   (ORGANIZATION Islamophobes/NNP)
#   ./.
#   They/PRP
#   are/VBP
#   decent/JJ
#   (GPE American/JJ)
#   citizens/NNS
#   who/WP
#   want/VBP
#   to/TO
#   uphold/VB
#   our/PRP$
#   tolerant/NN
#   values/NNS
#   and/CC
#   keep/VB
#   our/PRP$
#   country/NN
#   safe/JJ
#   ./.
#   People/NNS
#   who/WP
#   support/VBP
#   the/DT
#   police/NN
#   ,/,
#   and/CC
#   who/WP
#   want/VBP
#   crime/NN
#   reduced/VBN
#   ,/,
#   are/VBP
#   not/RB
#   prejudiced/VBN
#   ./.
#   They/PRP
#   are/VBP
#   concerned/JJ
#   and/CC
#   loving/JJ
#   citizens/NNS
#   whose/WP$
#   hearts/NNS
#   break/VBP
#   every/DT
#   time/NN
#   an/DT
#   innocent/JJ
#   child/NN
#   is/VBZ
#   lost/VBN
#   to/TO
#   preventable/JJ
#   violence/NN
#   ./.
#   Yet/CC
#   ,/,
#   while/IN
#   she/PRP
#   lives/VBZ
#   behind/IN
#   gates/NNS
#   and/CC
#   walls/NNS
#   and/CC
#   guards/NNS
#   ,/,
#   and/CC
#   raises/VBZ
#   millions/NNS
#   from/IN
#   hedge/NN
#   fund/NN
#   managers/NNS
#   and/CC
#   (ORGANIZATION Wall/NNP)
#   Street/NNP
#   donors/NNS
#   ,/,
#   she/PRP
#   slanders/NNS
#   and/CC
#   smears/NNS
#   working/VBG
#   people/NNS
#   who/WP
#   just/RB
#   want/VBP
#   a/DT
#   fraction/NN
#   of/IN
#   the/DT
#   security/NN
#   enjoyed/VBN
#   by/IN
#   our/PRP$
#   politicians/NNS
#   ./.
#   Her/PRP$
#   comments/NNS
#   displayed/VBD
#   the/DT
#   same/JJ
#   sense/NN
#   of/IN
#   arrogance/NN
#   and/CC
#   entitlement/NN
#   that/WDT
#   led/VBD
#   her/PRP
#   to/TO
#   violate/VB
#   federal/JJ
#   law/NN
#   as/IN
#   Secretary/NNP
#   of/IN
#   (GPE State/NNP)
#   ,/,
#   hide/NN
#   and/CC
#   delete/VB
#   her/PRP$
#   emails/NNS
#   ,/,
#   destroy/VB
#   her/PRP$
#   phones/NNS
#   with/IN
#   a/DT
#   hammer/NN
#   ,/,
#   put/VBD
#   classified/VBN
#   information/NN
#   in/IN
#   the/DT
#   reach/NN
#   of/IN
#   our/PRP$
#   enemies/NNS
#   ,/,
#   lie/NN
#   to/TO
#   (ORGANIZATION Congress/NNP)
#   ,/,
#   and/CC
#   sell/VB
#   government/NN
#   favors/NNS
#   and/CC
#   access/NN
#   through/IN
#   the/DT
#   (PERSON Clinton/NNP Foundation/NNP)
#   ./.
#   It/PRP
#   's/VBZ
#   the/DT
#   same/JJ
#   attitude/NN
#   of/IN
#   arrogance/NN
#   and/CC
#   entitlement/NN
#   that/IN
#   explains/VBZ
#   why/WRB
#   she/PRP
#   has/VBZ
#   never/RB
#   taken/VBN
#   accountability/NN
#   for/IN
#   the/DT
#   disasters/NNS
#   she/PRP
#   created/VBD
#   in/IN
#   (GPE Libya/NNP)
#   ,/,
#   (GSP Syria/NNP)
#   ,/,
#   (GPE Iraq/NNP)
#   ,/,
#   (GPE Iran/NNP)
#   and/CC
#   all/DT
#   over/IN
#   the/DT
#   world/NN
#   ./.
#   It/PRP
#   's/VBZ
#   the/DT
#   same/JJ
#   reason/NN
#   why/WRB
#   she/PRP
#   wo/MD
#   n't/RB
#   take/VB
#   responsibility/NN
#   for/IN
#   her/PRP$
#   central/JJ
#   role/NN
#   in/IN
#   unleashing/JJ
#   (ORGANIZATION ISIS/NNP)
#   ./.
#   Her/PRP$
#   policies/NNS
#   have/VBP
#   created/VBN
#   disaster/NN
#   overseas/RB
#   ,/,
#   and/CC
#   poverty/NN
#   at/IN
#   home/NN
#   ./.
#   I/PRP
#   am/VBP
#   running/VBG
#   to/TO
#   reverse/VB
#   these/DT
#   failures/NNS
#   ,/,
#   and/CC
#   create/VB
#   a/DT
#   (GPE New/NNP)
#   (GPE American/JJ)
#   future/NN
#   ./.
#   That/IN
#   future/JJ
#   begins/VBZ
#   with/IN
#   prosperity/NN
#   at/IN
#   home/NN
#   ./.
#   My/PRP$
#   economic/JJ
#   agenda/NN
#   can/MD
#   be/VB
#   summed/VBN
#   up/RP
#   in/IN
#   three/CD
#   words/NNS
#   :/:
#   jobs/NNS
#   ,/,
#   jobs/NNS
#   ,/,
#   jobs/NNS
#   ./.
#   One/CD
#   of/IN
#   my/PRP$
#   highest/JJS
#   priorities/NNS
#   is/VBZ
#   to/TO
#   bring/VB
#   jobs/NNS
#   into/IN
#   our/PRP$
#   inner/JJ
#   cities/NNS
#   ./.
#   African-Americans/JJ
#   communities/NNS
#   have/VBP
#   suffered/VBN
#   horribly/RB
#   as/IN
#   a/DT
#   result/NN
#   of/IN
#   failed/VBN
#   (ORGANIZATION Democratic/JJ)
#   leadership/NN
#   ./.
#   Democrats/NNPS
#   have/VBP
#   run/VBN
#   these/DT
#   inner/JJ
#   cities/NNS
#   for/IN
#   half/PDT
#   a/DT
#   century/NN
#   ./.
#   They/PRP
#   control/VBP
#   the/DT
#   mayors/NNS
#   '/POS
#   offices/NNS
#   ,/,
#   the/DT
#   school/NN
#   boards/NNS
#   ,/,
#   the/DT
#   city/NN
#   councils/NNS
#   ,/,
#   and/CC
#   the/DT
#   seats/NNS
#   in/IN
#   (ORGANIZATION Congress/NNP)
#   -/:
#   and/CC
#   all/DT
#   they/PRP
#   have/VBP
#   delivered/VBN
#   is/VBZ
#   more/RBR
#   poverty/NN
#   ,/,
#   more/JJR
#   crime/NN
#   ,/,
#   and/CC
#   more/RBR
#   failing/JJ
#   schools/NNS
#   ./.
#   45/CD
#   %/NN
#   of/IN
#   African-American/JJ
#   children/NNS
#   under/IN
#   the/DT
#   age/NN
#   of/IN
#   6/CD
#   now/RB
#   live/VBP
#   in/IN
#   poverty/NN
#   ./.
#   More/JJR
#   than/IN
#   3,000/CD
#   have/VBP
#   been/VBN
#   shot/VBN
#   in/IN
#   (GPE Chicago/NNP)
#   this/DT
#   year/NN
#   alone/RB
#   ./.
#   58/CD
#   %/NN
#   of/IN
#   African-American/JJ
#   youth/NN
#   are/VBP
#   not/RB
#   working/VBG
#   ./.
#   These/DT
#   are/VBP
#   the/DT
#   results/NNS
#   of/IN
#   the/DT
#   policies/NNS
#   embraced/VBN
#   by/IN
#   (PERSON Hillary/NNP Clinton/NNP)
#   ,/,
#   and/CC
#   everyone/NN
#   knows/VBZ
#   that/IN
#   if/IN
#   she/PRP
#   's/VBZ
#   elected/VBN
#   the/DT
#   inner/JJ
#   cities/NNS
#   will/MD
#   get/VB
#   nothing/NN
#   but/CC
#   more/JJR
#   pain/NN
#   and/CC
#   more/JJR
#   suffering/NN
#   ./.
#   (PERSON Hillary/NNP Clinton/NNP)
#   has/VBZ
#   been/VBN
#   there/RB
#   in/IN
#   (GPE Washington/NNP)
#   for/IN
#   30/CD
#   years/NNS
#   -/:
#   her/PRP$
#   disastrous/JJ
#   record/NN
#   speaks/NN
#   for/IN
#   itself/PRP
#   ./.
#   The/DT
#   only/JJ
#   people/NNS
#   she/PRP
#   delivers/NNS
#   for/IN
#   is/VBZ
#   her/PRP$
#   donors/NNS
#   ./.
#   I/PRP
#   am/VBP
#   going/VBG
#   to/TO
#   deliver/VB
#   for/IN
#   you/PRP
#   ,/,
#   the/DT
#   (GPE American/JJ)
#   people/NNS
#   ./.
#   If/IN
#   we/PRP
#   lower/VBP
#   our/PRP$
#   taxes/NNS
#   ,/,
#   remove/VB
#   destructive/JJ
#   regulations/NNS
#   ,/,
#   unleash/VBP
#   the/DT
#   vast/JJ
#   treasure/NN
#   of/IN
#   (GPE American/NNP)
#   energy/NN
#   ,/,
#   and/CC
#   negotiate/JJ
#   trade/NN
#   deals/NNS
#   that/WDT
#   put/VBD
#   (ORGANIZATION America/NNP First/NNP)
#   ,/,
#   then/RB
#   there/EX
#   is/VBZ
#   no/DT
#   limit/NN
#   to/TO
#   the/DT
#   number/NN
#   of/IN
#   jobs/NNS
#   we/PRP
#   can/MD
#   create/VB
#   and/CC
#   the/DT
#   amount/NN
#   of/IN
#   prosperity/NN
#   we/PRP
#   can/MD
#   unleash/VB
#   ./.
#   My/PRP$
#   first/JJ
#   day/NN
#   in/IN
#   office/NN
#   ,/,
#   I/PRP
#   am/VBP
#   going/VBG
#   to/TO
#   order/NN
#   a/DT
#   review/NN
#   of/IN
#   every/DT
#   single/JJ
#   regulation/NN
#   issued/VBN
#   over/IN
#   the/DT
#   last/JJ
#   eight/CD
#   years/NNS
#   ./.
#   All/DT
#   needless/JJ
#   ,/,
#   job-killing/JJ
#   regulations/NNS
#   will/MD
#   be/VB
#   cancelled/VBN
#   ./.
#   Millions/NNS
#   of/IN
#   new/JJ
#   jobs/NNS
#   will/MD
#   come/VB
#   pouring/NN
#   in/IN
#   ./.
#   We/PRP
#   are/VBP
#   going/VBG
#   to/TO
#   lift/VB
#   the/DT
#   restrictions/NNS
#   on/IN
#   (GPE American/NNP)
#   energy/NN
#   -/:
#   which/WDT
#   means/VBZ
#   at/IN
#   least/JJS
#   another/DT
#   half/NN
#   a/DT
#   million/CD
#   new/JJ
#   jobs/NNS
#   a/DT
#   year/NN
#   ./.
#   That/DT
#   's/VBZ
#   just/RB
#   the/DT
#   beginning/NN
#   ./.
#   Also/RB
#   on/IN
#   my/PRP$
#   first/JJ
#   day/NN
#   ,/,
#   I/PRP
#   am/VBP
#   going/VBG
#   to/TO
#   ask/VB
#   (ORGANIZATION Congress/NNP)
#   to/TO
#   send/VB
#   me/PRP
#   a/DT
#   bill/NN
#   to/TO
#   immediately/RB
#   repeal/VB
#   and/CC
#   replace/VB
#   disastrous/JJ
#   (ORGANIZATION Obamacare/NNP)
#   -/:
#   this/DT
#   will/MD
#   instantly/RB
#   save/VB
#   another/DT
#   2/CD
#   million/CD
#   jobs/NNS
#   ./.
#   I/PRP
#   am/VBP
#   also/RB
#   going/VBG
#   to/TO
#   completely/RB
#   reform/VB
#   our/PRP$
#   trade/NN
#   deals/NNS
#   ./.
#   We/PRP
#   are/VBP
#   going/VBG
#   to/TO
#   renegotiate/VB
#   (ORGANIZATION NAFTA/NNP)
#   ,/,
#   stand/VBP
#   up/RP
#   to/TO
#   (GPE China/NNP)
#   ,/,
#   and/CC
#   keep/VB
#   (GPE America/NNP)
#   out/IN
#   of/IN
#   the/DT
#   (ORGANIZATION TPP/NNP)
#   ./.
#   We/PRP
#   do/VBP
#   n't/RB
#   need/VB
#   another/DT
#   massive/JJ
#   multinational/NN
#   deal/NN
#   that/WDT
#   ties/VBZ
#   us/PRP
#   up/RP
#   and/CC
#   binds/VBZ
#   us/PRP
#   down/RP
#   ./.
#   Another/DT
#   major/JJ
#   reform/NN
#   is/VBZ
#   going/VBG
#   to/TO
#   be/VB
#   school/NN
#   choice/NN
#   ./.
#   I/PRP
#   've/VBP
#   outlined/VBN
#   a/DT
#   plan/NN
#   to/TO
#   provide/VB
#   every/DT
#   disadvantaged/JJ
#   child/NN
#   in/IN
#   (GPE America/NNP)
#   the/DT
#   freedom/NN
#   to/TO
#   choose/VB
#   the/DT
#   private/JJ
#   ,/,
#   public/JJ
#   ,/,
#   magnet/NN
#   or/CC
#   religious/JJ
#   school/NN
#   of/IN
#   his/PRP$
#   or/CC
#   her/PRP$
#   choice/NN
#   ./.
#   This/DT
#   will/MD
#   help/VB
#   lift/VB
#   millions/NNS
#   of/IN
#   poor/JJ
#   African-American/JJ
#   and/CC
#   Hispanic/JJ
#   children/NNS
#   out/IN
#   of/IN
#   poverty/NN
#   ./.
#   Since/IN
#   President/NNP
#   (PERSON Obama/NNP)
#   came/VBD
#   into/IN
#   office/NN
#   ,/,
#   another/DT
#   2/CD
#   million/CD
#   Hispanic-Americans/NNS
#   have/VBP
#   fallen/VBN
#   into/IN
#   poverty/NN
#   ./.
#   This/DT
#   is/VBZ
#   unacceptable/JJ
#   ./.
#   To/TO
#   the/DT
#   Hispanic/NNP
#   community/NN
#   I/PRP
#   say/VBP
#   :/:
#   we/PRP
#   are/VBP
#   going/VBG
#   to/TO
#   protect/VB
#   your/PRP$
#   jobs/NNS
#   ,/,
#   we/PRP
#   are/VBP
#   going/VBG
#   to/TO
#   build/VB
#   up/RP
#   your/PRP$
#   schools/NNS
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   going/VBG
#   to/TO
#   deliver/VB
#   safety/NN
#   and/CC
#   opportunity/NN
#   for/IN
#   your/PRP$
#   children/NNS
#   ./.
#   Earlier/RBR
#   this/DT
#   week/NN
#   ,/,
#   I/PRP
#   also/RB
#   rolled/VBD
#   out/RP
#   a/DT
#   plan/NN
#   to/TO
#   help/VB
#   our/PRP$
#   mothers/NNS
#   and/CC
#   our/PRP$
#   families/NNS
#   get/VBP
#   affordable/JJ
#   ,/,
#   quality/NN
#   childcare/NN
#   for/IN
#   their/PRP$
#   children/NNS
#   ./.
#   On/IN
#   policy/NN
#   after/IN
#   policy/NN
#   ,/,
#   we/PRP
#   are/VBP
#   going/VBG
#   to/TO
#   provide/VB
#   opportunity/NN
#   ,/,
#   prosperity/NN
#   and/CC
#   security/NN
#   for/IN
#   all/DT
#   Americans/NNPS
#   ./.
#   We/PRP
#   are/VBP
#   also/RB
#   going/VBG
#   to/TO
#   stand/VB
#   with/IN
#   the/DT
#   (GPE Cuban/NNP)
#   people/NNS
#   in/IN
#   their/PRP$
#   fight/NN
#   against/IN
#   communist/JJ
#   oppression/NN
#   ./.
#   The/DT
#   President/NNP
#   's/POS
#   one-sided/JJ
#   deal/NN
#   for/IN
#   (GPE Cuba/NNP)
#   benefits/NNS
#   only/RB
#   the/DT
#   (ORGANIZATION Castro/NNP Regime/NNP)
#   ./.
#   But/CC
#   all/DT
#   of/IN
#   the/DT
#   concessions/NNS
#   that/WDT
#   (PERSON Barack/NNP Obama/NNP)
#   has/VBZ
#   granted/VBN
#   the/DT
#   (ORGANIZATION Castro/NNP)
#   Regime/NNP
#   were/VBD
#   done/VBN
#   through/IN
#   executive/NN
#   order/NN
#   ,/,
#   which/WDT
#   means/VBZ
#   the/DT
#   next/JJ
#   President/NNP
#   can/MD
#   reverse/VB
#   them/PRP
#   -/:
#   and/CC
#   that/DT
#   is/VBZ
#   what/WP
#   I/PRP
#   will/MD
#   do/VB
#   ,/,
#   unless/IN
#   the/DT
#   (ORGANIZATION Castro/NNP)
#   Regime/NNP
#   meets/VBZ
#   our/PRP$
#   demands/NNS
#   ./.
#   Those/DT
#   demands/NNS
#   will/MD
#   include/VB
#   religious/JJ
#   and/CC
#   political/JJ
#   freedom/NN
#   for/IN
#   the/DT
#   (GPE Cuban/NNP)
#   people/NNS
#   ./.
#   Let/VB
#   's/POS
#   also/RB
#   talk/VBP
#   about/IN
#   (PERSON Venezuela/NNP)
#   ./.
#   (PERSON Venezuela/NNP)
#   is/VBZ
#   a/DT
#   beautiful/JJ
#   ,/,
#   vibrant/JJ
#   ,/,
#   and/CC
#   resource-rich/JJ
#   country/NN
#   ,/,
#   filled/VBN
#   with/IN
#   amazing/JJ
#   and/CC
#   hardworking/VBG
#   people/NNS
#   ./.
#   But/CC
#   (PERSON Venezuela/NNP)
#   has/VBZ
#   been/VBN
#   run/VBN
#   into/IN
#   the/DT
#   ground/NN
#   by/IN
#   socialists/NNS
#   ./.
#   The/DT
#   next/JJ
#   President/NNP
#   of/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   must/MD
#   stand/VB
#   in/IN
#   solidarity/NN
#   with/IN
#   all/DT
#   people/NNS
#   oppressed/VBN
#   in/IN
#   our/PRP$
#   hemisphere/NN
#   ,/,
#   and/CC
#   I/PRP
#   will/MD
#   stand/VB
#   with/IN
#   the/DT
#   oppressed/JJ
#   people/NNS
#   of/IN
#   (GPE Venezuela/NNP)
#   yearning/VBG
#   to/TO
#   be/VB
#   free/JJ
#   ./.
#   Here/RB
#   ,/,
#   in/IN
#   (GPE America/NNP)
#   ,/,
#   I/PRP
#   will/MD
#   push/VB
#   to/TO
#   expand/VB
#   freedom/NN
#   for/IN
#   all/DT
#   of/IN
#   our/PRP$
#   people/NNS
#   ./.
#   I/PRP
#   am/VBP
#   going/VBG
#   to/TO
#   lower/VB
#   you/PRP
#   taxes/NNS
#   ;/:
#   I/PRP
#   am/VBP
#   going/VBG
#   to/TO
#   get/VB
#   rid/JJ
#   of/IN
#   massive/JJ
#   amounts/NNS
#   of/IN
#   unnecessary/JJ
#   regulations/NNS
#   ,/,
#   on/IN
#   business/NN
#   and/CC
#   in/IN
#   your/PRP$
#   life/NN
#   ;/:
#   I/PRP
#   'm/VBP
#   going/VBG
#   to/TO
#   repeal/VB
#   and/CC
#   replace/VB
#   (GPE Obamacare/NNP)
#   ;/:
#   I/PRP
#   'm/VBP
#   going/VBG
#   to/TO
#   appoint/VB
#   Justices/NNS
#   to/TO
#   the/DT
#   (ORGANIZATION Supreme/NNP)
#   Court/NNP
#   who/WP
#   will/MD
#   follow/VB
#   the/DT
#   (ORGANIZATION Constitution/NNP)
#   ;/:
#   I/PRP
#   'm/VBP
#   going/VBG
#   to/TO
#   rebuild/VB
#   our/PRP$
#   depleted/JJ
#   military/JJ
#   and/CC
#   take/VB
#   care/NN
#   of/IN
#   our/PRP$
#   vets/NNS
#   ;/:
#   I/PRP
#   'm/VBP
#   going/VBG
#   to/TO
#   save/VB
#   your/PRP$
#   2nd/CD
#   amendment/NN
#   ;/:
#   I/PRP
#   'm/VBP
#   going/VBG
#   to/TO
#   stop/VB
#   illegal/JJ
#   immigration/NN
#   and/CC
#   drugs/NNS
#   coming/VBG
#   into/IN
#   our/PRP$
#   country/NN
#   ,/,
#   and/CC
#   yes/RB
#   ,/,
#   we/PRP
#   will/MD
#   build/VB
#   the/DT
#   wall/NN
#   and/CC
#   I/PRP
#   'm/VBP
#   going/VBG
#   to/TO
#   renegotiate/VB
#   our/PRP$
#   disastrous/JJ
#   trade/NN
#   deals/NNS
#   ,/,
#   especially/RB
#   (ORGANIZATION NAFTA/NNP)
#   -/:
#   and/CC
#   we/PRP
#   will/MD
#   make/VB
#   great/JJ
#   trade/NN
#   deals/NNS
#   that/WDT
#   put/VBD
#   the/DT
#   (GPE American/NNP)
#   worker/NN
#   first/RB
#   ./.
#   We/PRP
#   will/MD
#   rebuild/VB
#   our/PRP$
#   roads/NNS
#   ,/,
#   bridges/NNS
#   ,/,
#   tunnels/NNS
#   ,/,
#   highways/NNS
#   ,/,
#   airports/NNS
#   ,/,
#   schools/NNS
#   and/CC
#   hospitals/NNS
#   ./.
#   (GPE American/JJ)
#   cars/NNS
#   will/MD
#   travel/VB
#   the/DT
#   roads/NNS
#   ,/,
#   (GPE American/NNP)
#   planes/NNS
#   will/MD
#   soar/VB
#   in/IN
#   the/DT
#   skies/NNS
#   ,/,
#   and/CC
#   (GPE American/NNP)
#   ships/NNS
#   will/MD
#   patrol/VB
#   the/DT
#   seas/NNS
#   ./.
#   (GPE American/JJ)
#   steel/NN
#   will/MD
#   send/VB
#   new/JJ
#   skyscrapers/NNS
#   into/IN
#   the/DT
#   clouds/NN
#   ./.
#   (GPE American/JJ)
#   hands/NNS
#   will/MD
#   rebuild/VB
#   this/DT
#   nation/NN
#   -/:
#   and/CC
#   (GPE American/NNP)
#   energy/NN
#   ,/,
#   mined/VBN
#   from/IN
#   (GPE American/JJ)
#   sources/NNS
#   ,/,
#   will/MD
#   power/NN
#   this/DT
#   nation/NN
#   ./.
#   (GPE American/JJ)
#   workers/NNS
#   will/MD
#   be/VB
#   hired/VBN
#   to/TO
#   do/VB
#   the/DT
#   job/NN
#   ./.
#   We/PRP
#   will/MD
#   put/VB
#   new/JJ
#   (GPE American/JJ)
#   steel/NN
#   into/IN
#   the/DT
#   spine/NN
#   of/IN
#   this/DT
#   country/NN
#   ./.
#   I/PRP
#   will/MD
#   fight/VB
#   for/IN
#   every/DT
#   neglected/JJ
#   part/NN
#   of/IN
#   this/DT
#   nation/NN
#   -/:
#   and/CC
#   I/PRP
#   will/MD
#   fight/VB
#   to/TO
#   bring/VB
#   us/PRP
#   all/DT
#   together/RB
#   as/IN
#   One/CD
#   (ORGANIZATION American/JJ People/NNP)
#   ./.
#   Imagine/VB
#   what/WP
#   our/PRP$
#   country/NN
#   could/MD
#   accomplish/VB
#   if/IN
#   we/PRP
#   started/VBD
#   working/VBG
#   together/RB
#   as/IN
#   One/CD
#   People/NN
#   ,/,
#   under/IN
#   One/CD
#   God/NNP
#   ,/,
#   saluting/VBG
#   One/CD
#   (ORGANIZATION American/JJ Flag/NNP)
#   ./.
#   It/PRP
#   is/VBZ
#   time/NN
#   to/TO
#   break/VB
#   with/IN
#   the/DT
#   bitter/JJ
#   failures/NNS
#   of/IN
#   the/DT
#   past/NN
#   ,/,
#   and/CC
#   to/TO
#   embrace/VB
#   a/DT
#   new/JJ
#   ,/,
#   inclusive/JJ
#   and/CC
#   prosperous/JJ
#   (GPE American/JJ)
#   future/NN
#   ./.
#   (PERSON Jobs/NNP)
#   will/MD
#   return/VB
#   ,/,
#   incomes/NNS
#   will/MD
#   rise/VB
#   ,/,
#   and/CC
#   new/JJ
#   factories/NNS
#   will/MD
#   come/VB
#   rushing/VBG
#   back/RB
#   to/TO
#   our/PRP$
#   shores/NNS
#   ./.
#   Once/RB
#   more/JJR
#   ,/,
#   we/PRP
#   will/MD
#   have/VB
#   a/DT
#   government/NN
#   of/IN
#   ,/,
#   by/IN
#   and/CC
#   for/IN
#   the/DT
#   people/NNS
#   ./.
#   We/PRP
#   (PERSON Will/NNP Make/NNP America/NNP Prosperous/NNP Again/NNP)
#   ./.
#   We/PRP
#   (PERSON Will/NNP Make/NNP America/NNP Strong/NNP Again/NNP)
#   ./.
#   And/CC
#   (PERSON Will/NNP Make/NNP America/NNP Great/NNP Again/NNP)
#   ./.
#   Thank/NNP
#   you/PRP
#   ,/,
#   and/CC
#   (PERSON God/NNP Bless/NNP)
#   !/.
#   /NN)

# %%
def get_continuous_chunks(text, label):
    chunked = ne_chunk(pos_tag(word_tokenize(text)))
    prev = None
    continuous_chunk = []
    current_chunk = []

    for subtree in chunked:
        if type(subtree) == Tree and subtree.label() == label:
            current_chunk.append(" ".join([token for token, pos in subtree.leaves()]))
        elif current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue

    return continuous_chunk

# %%
get_continuous_chunks(strEx, 'GPE')
# Out:
# ['Florida',
#  'Miami',
#  'Florida Little Haiti',
#  'American',
#  'Honor',
#  'American Americans',
#  'American State',
#  'Libya',
#  'Iraq',
#  'Iran',
#  'New American',
#  'Chicago',
#  'Washington',
#  'American American',
#  'American China',
#  'America',
#  'America Cuban',
#  'Cuba',
#  'Cuban',
#  'United States',
#  'Venezuela',
#  'America Obamacare',
#  'American American American',
#  'American American American American']

# %%
get_continuous_chunks(strEx, 'ORGANIZATION')
# Out:
# ['Veterans',
#  'Hispanic',
#  'Medal',
#  'Admirals',
#  'Democratic',
#  'Islamophobes',
#  'Wall',
#  'Congress',
#  'ISIS',
#  'Democratic Congress',
#  'America First',
#  'Congress Obamacare',
#  'NAFTA',
#  'TPP',
#  'Castro Regime',
#  'Castro',
#  'Castro Supreme',
#  'Constitution',
#  'NAFTA American People',
#  'American Flag']
